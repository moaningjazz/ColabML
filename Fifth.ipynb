# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn import datasets
iris = datasets.load_iris()
import random
import math
import pylab as pl
from matplotlib.colors import ListedColormap
import time


dataset = pd.read_csv('ABBREV.csv', sep=';', encoding='UTF-8')
dataset
# Out:
#       NDB_No                   Shrt_Desc  ...              GmWt_Desc2  Refuse_Pct
# 0       1001            BUTTER.WITH SALT  ...                  1 tbsp         0.0
# 1       1002      BUTTER.WHIPPED.W/ SALT  ...                  1 tbsp         0.0
# 2       1003        BUTTER OIL.ANHYDROUS  ...                   1 cup         0.0
# 3       1004                 CHEESE.BLUE  ...            1 cubic inch         0.0
# 4       1005                CHEESE.BRICK  ...         1 cup. shredded         0.0
# ...      ...                         ...  ...                     ...         ...
# 8785   83110             MACKEREL.SALTED  ...  1 cubic inch. boneless         0.0
# 8786   90240  SCALLOP.(BAY&SEA).CKD.STMD  ...                       0         0.0
# 8787   90480                  SYRUP.CANE  ...                       0         0.0
# 8788   90560                   SNAIL.RAW  ...                       0         0.0
# ...

# %% [markdown]
# Проверка влияния нормализации

# %%
dimensions = ['Sugar_Tot_(g)','Cholestrl_(mg)']
Class = "Калорийность"
testPercent = 0.2
norm = True

data = createData(dataset,dimensions,Class, norm)
showData(data)
testData,trainData = splitData(data, testPercent)
tree = build_tree(trainData, 20, 1)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [0.0006012024048096192, 0.06935483870967742, 1]
# Кол-во данных: 8790
# Длинна тестовой выборки: 1722
# Длинна тренировочной выборки: 7068
# Время выполнения:  3.576678991317749
# Точность предугадывания:  0.653084323712507

# %%
dimensions = ['Sugar_Tot_(g)','Cholestrl_(mg)']
Class = "Калорийность"
testPercent = 0.2
norm = False

data = createData(dataset,dimensions,Class, norm)
showData(data)
testData,trainData = splitData(data, testPercent)
tree = build_tree(trainData, 20, 1)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [0.06, 215, 1]
# Кол-во данных: 8790
# Длинна тестовой выборки: 1742
# Длинна тренировочной выборки: 7048
# Время выполнения:  4.171535491943359
# Точность предугадывания:  0.655788876276958

# %% [markdown]
# C нормализацией результаты лучше

# %% [markdown]
# Проверка различных признаков

# %%
dimensions = ['Energ_Kcal',	'Protein_(g)']
Class = "Калорийность"
testPercent = 0.2
norm = False

data = createData(dataset,dimensions,Class, norm)
showData(data)
testData,trainData = splitData(data, testPercent)
tree = build_tree(trainData, 7, 1)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [717, 0.85, 1]
# Кол-во данных: 8790
# Длинна тестовой выборки: 1761
# Длинна тренировочной выборки: 7029
# Время выполнения:  2.0916810035705566
# Точность предугадывания:  1.0

# %%
dimensions = ['Energ_Kcal', 'Sugar_Tot_(g)']
Class = "Калорийность"
testPercent = 0.2
norm = False

data = createData(dataset,dimensions,Class, norm)
showData(data)
testData,trainData = splitData(data, testPercent)
tree = build_tree(trainData, 7, 1)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [717, 0.06, 1]
# Кол-во данных: 8790
# Длинна тестовой выборки: 1799
# Длинна тренировочной выборки: 6991
# Время выполнения:  2.167344808578491
# Точность предугадывания:  1.0

# %%
dimensions = ['Water_(g)','Protein_(g)']
Class = "Калорийность"
testPercent = 0.2
norm = False

data = createData(dataset,dimensions,Class, norm)
showData(data)
testData,trainData = splitData(data, testPercent)
tree = build_tree(trainData, 7, 1)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [15.87, 0.85, 1]
# Кол-во данных: 8790
# Длинна тестовой выборки: 1678
# Длинна тренировочной выборки: 7112
# Время выполнения:  2.649580240249634
# Точность предугадывания:  0.9438976377952756

# %%
dimensions = ['Calcium_(mg)', 'Protein_(g)']
Class = "Калорийность"
testPercent = 0.2
norm = False

data = createData(dataset,dimensions,Class, norm)
showData(data)
testData,trainData = splitData(data, testPercent)
tree = build_tree(trainData, 7, 1)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [24, 0.85, 1]
# Кол-во данных: 8790
# Длинна тестовой выборки: 1764
# Длинна тренировочной выборки: 7026
# Время выполнения:  2.7540392875671387
# Точность предугадывания:  0.7324224309706804

# %% [markdown]
# Увеличение глубины дерева

# %%
dimensions = ['Calcium_(mg)', 'Protein_(g)']
Class = "Калорийность"
testPercent = 0.2
norm = False

data = createData(dataset,dimensions,Class, norm)
testData,trainData = splitData(data, testPercent)
tree = build_tree(trainData, 20, 1)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [24, 0.85, 1]
# Кол-во данных: 8790
# Длинна тестовой выборки: 1785
# Длинна тренировочной выборки: 7005
# Время выполнения:  3.051232099533081
# Точность предугадывания:  0.6942184154175589

# %%
dimensions = ['Calcium_(mg)', 'Protein_(g)']
Class = "Калорийность"
testPercent = 0.2
norm = False

data = createData(dataset,dimensions,Class, norm)
testData,trainData = splitData(data, testPercent)
tree = build_tree(trainData, 50, 1)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [24, 0.85, 1]
# Кол-во данных: 8790
# Длинна тестовой выборки: 1752
# Длинна тренировочной выборки: 7038
# Время выполнения:  2.8354852199554443
# Точность предугадывания:  0.6986359761295823

# %%
dimensions = ['Calcium_(mg)', 'Protein_(g)']
Class = "Калорийность"
testPercent = 0.2
norm = False

data = createData(dataset,dimensions,Class, norm)
testData,trainData = splitData(data, testPercent)
tree = build_tree(trainData, 100, 1)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [24, 0.85, 1]
# Кол-во данных: 8790
# Длинна тестовой выборки: 1730
# Длинна тренировочной выборки: 7060
# Время выполнения:  2.7041361331939697
# Точность предугадывания:  0.6954674220963173

# %%
dimensions = ['Calcium_(mg)', 'Protein_(g)']
Class = "Калорийность"
testPercent = 0.2
norm = False

data = createData(dataset,dimensions,Class, norm)
testData,trainData = splitData(data, testPercent)
tree = build_tree(trainData, 150, 1)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [24, 0.85, 1]
# Кол-во данных: 8790
# Длинна тестовой выборки: 1733
# Длинна тренировочной выборки: 7057
# Время выполнения:  2.7460455894470215
# Точность предугадывания:  0.6876859855462661

# %% [markdown]
# Лучший резуьтат -- 50

# %% [markdown]
# Увеличение минимального размера

# %%
dimensions = ['Calcium_(mg)', 'Protein_(g)']
Class = "Калорийность"
testPercent = 0.2
norm = False

data = createData(dataset,dimensions,Class, norm)
testData,trainData = splitData(data, testPercent)
tree = build_tree(trainData, 50, 5)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [24, 0.85, 1]
# Кол-во данных: 8790
# Длинна тестовой выборки: 1814
# Длинна тренировочной выборки: 6976
# Время выполнения:  3.2928366661071777
# Точность предугадывания:  0.6900802752293578

# %%
dimensions = ['Calcium_(mg)', 'Protein_(g)']
Class = "Калорийность"
testPercent = 0.2
norm = False

data = createData(dataset,dimensions,Class, norm)
testData,trainData = splitData(data, testPercent)
tree = build_tree(trainData, 50, 10)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [24, 0.85, 1]
# Кол-во данных: 8790
# Длинна тестовой выборки: 1813
# Длинна тренировочной выборки: 6977
# Время выполнения:  3.022878646850586
# Точность предугадывания:  0.6967177870144762

# %%
dimensions = ['Calcium_(mg)', 'Protein_(g)']
Class = "Калорийность"
testPercent = 0.2
norm = False

data = createData(dataset,dimensions,Class, norm)
testData,trainData = splitData(data, testPercent)
tree = build_tree(trainData, 50, 20)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [24, 0.85, 1]
# Кол-во данных: 8790
# Длинна тестовой выборки: 1667
# Длинна тренировочной выборки: 7123
# Время выполнения:  2.849106788635254
# Точность предугадывания:  0.7041976695212692

# %% [markdown]
# Проверка на данном разбиении с классами

# %%
dataset3 = pd.read_csv('ABBREV_with_classes.csv', sep=';', encoding='UTF-8')
dataset3
# Out:
#       NDB_No  CLASS  ...              GmWt_Desc2  Refuse_Pct
# 0       1001      0  ...                  1 tbsp         0.0
# 1       1002      0  ...                  1 tbsp         0.0
# 2       1003     10  ...                   1 cup         0.0
# 3       1004      0  ...            1 cubic inch         0.0
# 4       1005      0  ...         1 cup. shredded         0.0
# ...      ...    ...  ...                     ...         ...
# 8785   83110     10  ...  1 cubic inch. boneless         0.0
# 8786   90240     10  ...                       0         0.0
# 8787   90480      0  ...                       0         0.0
# 8788   90560     10  ...                       0         0.0
# 8789   93600     10  ...                       0         0.0
#
# [8790 rows x 54 columns]

# %% [markdown]
# нормализация

# %%
dimensions = ['Protein_(g)','Iron_(mg)']
Class = "CLASS"
testPercent = 0.2
norm = False

data = createData(dataset3,dimensions,Class, norm)
testData,trainData = splitData(data, testPercent)
tree = build_tree(trainData, 50, 1)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [0.85, 0.02, 0]
# Кол-во данных: 8790
# Длинна тестовой выборки: 1796
# Длинна тренировочной выборки: 6994
# Время выполнения:  4.61726188659668
# Точность предугадывания:  0.5955104375178725

# %%
dimensions = ['Protein_(g)','Iron_(mg)']
Class = "CLASS"
testPercent = 0.2
norm = True

data = createData(dataset3,dimensions,Class, norm)
testData,trainData = splitData(data, testPercent)
tree = build_tree(trainData, 50, 1)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [0.009624094202898552, 0.00016181229773462783, 0]
# Кол-во данных: 8790
# Длинна тестовой выборки: 1718
# Длинна тренировочной выборки: 7072
# Время выполнения:  4.250430583953857
# Точность предугадывания:  0.6042138009049773

# %% [markdown]
# максимальная глубина дерева

# %%
dimensions = ['Protein_(g)','Iron_(mg)']
Class = "CLASS"
testPercent = 0.2
norm = True

data = createData(dataset3,dimensions,Class, norm)
testData,trainData = splitData(data, testPercent)
tree = build_tree(trainData, 20, 1)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [0.009624094202898552, 0.00016181229773462783, 0]
# Кол-во данных: 8790
# Длинна тестовой выборки: 1748
# Длинна тренировочной выборки: 7042
# Время выполнения:  4.525869846343994
# Точность предугадывания:  0.603095711445612

# %%
dimensions = ['Protein_(g)','Iron_(mg)']
Class = "CLASS"
testPercent = 0.2
norm = True

data = createData(dataset3,dimensions,Class, norm)
testData,trainData = splitData(data, testPercent)
tree = build_tree(trainData, 50, 1)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [0.009624094202898552, 0.00016181229773462783, 0]
# Кол-во данных: 8790
# Длинна тестовой выборки: 1730
# Длинна тренировочной выборки: 7060
# Время выполнения:  4.10615611076355
# Точность предугадывания:  0.5923512747875355

# %%
dimensions = ['Protein_(g)','Iron_(mg)']
Class = "CLASS"
testPercent = 0.2
norm = True

data = createData(dataset3,dimensions,Class, norm)
testData,trainData = splitData(data, testPercent)
tree = build_tree(trainData, 100, 1)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [0.009624094202898552, 0.00016181229773462783, 0]
# Кол-во данных: 8790
# Длинна тестовой выборки: 1759
# Длинна тренировочной выборки: 7031
# Время выполнения:  4.454115629196167
# Точность предугадывания:  0.596358981652681

# %%
dimensions = ['Protein_(g)','Iron_(mg)']
Class = "CLASS"
testPercent = 0.2
norm = True

data = createData(dataset3,dimensions,Class, norm)
testData,trainData = splitData(data, testPercent)
tree = build_tree(trainData, 150, 1)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [0.009624094202898552, 0.00016181229773462783, 0]
# Кол-во данных: 8790
# Длинна тестовой выборки: 1715
# Длинна тренировочной выборки: 7075
# Время выполнения:  4.4825732707977295
# Точность предугадывания:  0.5953356890459364

# %% [markdown]
# Метод ближайших соседей для ОГЭ

# %%
oge = pd.read_csv('5_OGE_2019.csv', index_col=0)
oge = pd.get_dummies(oge)
oge
# Out:
#      Код ОО  Код предмета  ...  Часть С_2(2)1(2)  Часть С_2(2)2(2)
# GIA                        ...
# 1    201033             5  ...                 0                 0
# 1    203063             5  ...                 0                 1
# 1    203063             5  ...                 0                 0
# 1    204023             5  ...                 0                 0
# 1    205015             5  ...                 0                 0
# ..      ...           ...  ...               ...               ...
# 1    247053             5  ...                 0                 0
# 1    247073             5  ...                 0                 0
# 1    247093             5  ...                 0                 1
# 1    247093             5  ...                 0                 1
# 1    247113             5  ...                 0                 0
#
# [5986 rows x 4332 columns]

# %%
def distEv (a, b):
  sum = 0
  for i in range(len(a)-1):
    sum += (a[i] - b[i])**2
  return math.sqrt(sum)

def distMa (a, b):
  sum = 0
  for i in range(len(a)-1):
    sum += abs(a[i] - b[i])
  return sum

def classifyKNN (trainData, testData, k, numberOfClasses, typeOfDist):
    start_time = time.time()

    #подсчет расстояния между точками
    testLabels = []	
    for testPoint in testData:
        #подсчет расстояния от текущей точки до всех остальных
        if (typeOfDist == 'Evklid'):
            testDist = [ [distEv(testPoint, trainData[i]), trainData[i][len(trainData[i])-1]] for i in range(len(trainData))]
        elif (typeOfDist == 'Manhattan'):
            testDist = [ [distMa(testPoint, trainData[i]), trainData[i][len(trainData[i])-1]] for i in range(len(trainData))]
        #сколько точек рядом каждого класса рядом с нашей точкой
        stat = [0 for i in range(numberOfClasses)]
        for d in sorted(testDist)[0:k]:
          stat[d[len(d)-1]] += 1
        #присваивается самый часто встречающийся класс среди к ближайших
        testLabels.append( sorted(zip(stat, range(numberOfClasses)), reverse=True)[0][1] )
    delta_time = time.time() - start_time
    print ('Время выполнения: ', delta_time)
    return testLabels

# %%
dimensions = ['Код ОО','Вариант','Оцека по 100']
Class = "Оцека по 5"
testPercent = 0.2
norm = True
k = 10
N = 6
Dist = 'Evklid'
data = createData(oge,dimensions,Class,norm)
print(data[0][len(data[0])-1])
showData(data)
trainData, testData = splitData(data, testPercent)

print('Метод к ближайших соседей:')
newTest = classifyKNN(trainData, testData, k, N, Dist)
accCheck(testData,newTest)

print('Метод дерева рещений:')
tree = build_tree(trainData, 9, 1)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in double_scalars
#   import sys
# Пример данных: [0.7945246084348063, 0.9051612748851455, nan, 4]
# Кол-во данных: 5986
# 4
# Длинна тестовой выборки: 1204
# Длинна тренировочной выборки: 4782
# Метод к ближайших соседей:
# Время выполнения:  17.715739250183105
# Точность предугадывания:  0.2666112956810631
# Метод дерева рещений:
# Время выполнения:  70.2848014831543
# Точность предугадывания:  0.4269102990033223

# %%
dimensions = ['Первичный балл','Код предмета', 'Вариант']
Class = "Оцека по 5"
testPercent = 0.2
norm = True
k = 10
N = 6
Dist = 'Evklid'
data = createData(oge,dimensions,Class,norm)
print(data[0][len(data[0])-1])
showData(data)
trainData, testData = splitData(data, testPercent)

print('Метод к ближайших соседей:')
newTest = classifyKNN(trainData, testData, k, N, Dist)
accCheck(testData,newTest)

print('Метод дерева рещений:')
tree = build_tree(trainData, 9, 1)
newTest = predict_by_tree(tree, testData)
accCheck(testData,newTest)
# Out:
# Пример данных: [0.6818181818181818, 1.0, 0.9051612748851455, 4]
# Кол-во данных: 5986
# 4
# Длинна тестовой выборки: 1172
# Длинна тренировочной выборки: 4814
# Метод к ближайших соседей:
# Время выполнения:  19.966170072555542
# Точность предугадывания:  1.0
# Метод дерева рещений:
# Время выполнения:  36.391321897506714
# Точность предугадывания:  1.0

# %% [markdown]
# Метод дерева решений выдаёт более качественный результат за более долгий промежуток времени.
# Метод к ближайших соседей более быстрый, но менее точный.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %%
def func(row):
    return 1 if int(row[3]) > 200 else 0

dataset["Калорийность"] = dataset.apply(func, axis=1)
dataset["Калорийность"].value_counts()
# Out:
# 0    4602
# 1    4188
# Name: Калорийность, dtype: int64

# %%
def createData(df, dimentions,Class, norm):
  data = []
  for index, row in df.iterrows():
      temp = [] 
      for i in range(len(dimentions)):
          temp.append(row[dimentions[i]])
      temp.append(int(row[Class]))
      data.append(temp)
  
  if (norm):
	  data = normalise(data)

  print("Пример данных:", data[0])
  print("Кол-во данных:", len(data))
  return data

# %%
def showData(data):
  pl.scatter([data[i][0] for i in range(len(data))],
                 [data[i][1] for i in range(len(data))],
                 c=[data[i][len(data[i])-1] for i in range(len(data))])
  pl.show()

# %%
def splitData(data, persent):
  trainData = []
  testData  = []
  for row in data:
      if random.random() < persent:
          testData.append(row)
      else:
          trainData.append(row)
  print ("Длинна тестовой выборки:",len(testData))
  print ("Длинна тренировочной выборки:",len(trainData))
  return trainData, testData

# %%
def gini_index(groups, classes):
	n_instances = float(sum([len(group) for group in groups]))
	gini = 0.0
	for group in groups:
		size = float(len(group))
		if size == 0:
			continue
		score = 0.0
		for class_val in classes:
			p = [row[-1] for row in group].count(class_val) / size
			score += p * p
		gini += (1.0 - score) * (size / n_instances)
	return gini

# %%
def test_split(index, value, dataset):
	left, right = list(), list()
	for row in dataset:
		if row[index] < value:
			left.append(row)
		else:
			right.append(row)
	return left, right

# %%
def get_split(dataset):
	class_values = list(set(row[-1] for row in dataset))
	b_index, b_value, b_score, b_groups = 999, 999, 999, None
	for index in range(len(dataset[0])-1):
		for row in dataset:
			groups = test_split(index, row[index], dataset)
			gini = gini_index(groups, class_values)
			if gini < b_score:
				b_index, b_value, b_score, b_groups = index, row[index], gini, groups
	return {'index':b_index, 'value':b_value, 'groups':b_groups}

# %%
def to_terminal(group):
	outcomes = [row[-1] for row in group]
	return max(set(outcomes), key=outcomes.count)

# %%
def split(node, max_depth, min_size, depth):
	left, right = node['groups']
	del(node['groups'])
	if not left or not right:
		node['left'] = node['right'] = to_terminal(left + right)
		return
	if depth >= max_depth:
		node['left'], node['right'] = to_terminal(left), to_terminal(right)
		return
	if len(left) <= min_size:
		node['left'] = to_terminal(left)
	else:
		node['left'] = get_split(left)
		split(node['left'], max_depth, min_size, depth+1)
	if len(right) <= min_size:
		node['right'] = to_terminal(right)
	else:
		node['right'] = get_split(right)
		split(node['right'], max_depth, min_size, depth+1)

# %%
def build_tree(train, max_depth, min_size):
	start_time = time.time()
	root = get_split(train)
	split(root, max_depth, min_size, 1)
	delta_time = time.time() - start_time
	print ('Время выполнения: ', delta_time)
	return root

# %%
def print_tree(node, depth=1):
	if isinstance(node, dict):
		print('%s[X%d < %.3f]' % ((depth*' ', (node['index']+1), node['value'])))
		print_tree(node['left'], depth+1)
		print_tree(node['right'], depth+1)
	else:
		print('%s[%s]' % ((depth*' ', node)))

# %%
def predict_by_tree(tree, data):
  labels = []
  for row in data:
    subtree = tree
    while True:
      if row[subtree['index']] < subtree['value']:
        if isinstance(subtree['left'], dict):
          subtree = subtree['left']
        else:
          labels.append(subtree['left'])
          break
      else:
        if isinstance(subtree['right'], dict):
          subtree = subtree['right']
        else:
          labels.append(subtree['right'])
          break
  return labels

# %%
def normalise(data):
    for i in range(len(data[0]) - 1):
        tempmax = 0
        for j in range(len(data)):
            tempmax = max(tempmax,data[j][i])
        for j in range(len(data)):
            data[j][i] /= tempmax
    return data

# %%
def accCheck(testData,newTest):
  accuracy = 0
  for i in range(len(testData)):
    if testData[i][len(testData[i])-1] == newTest[i]:
      accuracy += 1
  accuracy /= len(testData)
  print("Точность предугадывания: ", accuracy)
